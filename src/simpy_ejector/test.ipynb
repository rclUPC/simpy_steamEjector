# %%
from simpy_ejector import EjectorGeom, numSolvers, nozzleFactory, fluidProp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from simpy_ejector import EjectorGeom, numSolvers, nozzleFactory, fluidProp
#
# ModuleNotFoundError: No module named 'simpy_ejector'

# %%
FP = fluidProp.setup("Water")

# %%
out = fluidProp.getDh_from_TP( FP, T=300, p = 100)

# %%
print(f'water at 300K and 100 kPa : Density = {out[0]} kg/m3, spec enthalpy = {out[1]} kJ/kg')
# Out:
# water at 300K and 100 kPa : Density = 996.5563403888981 kg/m3, spec enthalpy = 112.65367968856859 kJ/kg

# %%
out = fluidProp.get_from_PS(FP,p=100,s=10000)

# %%
out
# Out:
# {'T': 1283.4638430874304, 'D': 0.16883149345085371, 'h': 4668.150763371713}

# %%
out = fluidProp.getTransport(FP,T=300,D=970)

# %%
out
# Out:
# (863.3188798794247, 0.5753088816491381)

# %%
out = fluidProp.getTD(FP,hm=200.0,P=10.0,debug=True)
# Out:
# Temp(K):45.806328923937826, Density 19.50845567774219 g/liter, quality: 0.3425532952217065 Speed of Sound None

# %%
out
# Out:
# {'T': 45.806328923937826,
#  'D': 19.50845567774219,
#  'q': 0.3425532952217065,
#  'c': None,
#  's': 0.6748858163548845}
