# %%
from simpy_ejector import nozzleSolver,NozzleParams, EjectorGeom, nozzleFactory, fluidProp, EjectorMixer, numSolvers

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import time
import importlib
import logging,sys

# %%
logging.basicConfig(stream = sys.stdout, level = logging.DEBUG)
logging.getLogger("matplotlib").setLevel(logging.ERROR)
logging.getLogger("PIL").setLevel(logging.ERROR)

# %%
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_rows', 140)
np.core.arrayprint._line_width = 180
np.set_printoptions(linewidth= 180)

# %%
nozzle = nozzleFactory.ConicConic(Rin = 1.0, Lcon=2.905, Rt = 0.2215, Ldiv = 1.4116, Rout = 0.2215 )
nozzle.setFriction( 1.0e-2 )
ejector = EjectorGeom(nozzle, Dm = 1.4 )
ejector.setMixer(mixerstart=5.514, mixerLen=11.2, diffuserLen=25.2, diffuserHeight=1.80)
ejectorPlot = ejector.draw()

# %%
pin = 300.0  # kPa  
Tin = 25.0 + 273.15   # Kelvin 
Tsuc =  110 + 273.15 #  suction temperature
Psuc =  100 # suction pressure kPa
fluid = "Water"
RP = fluidProp.setup(fluid)
[Din, hin] = fluidProp.getDh_from_TP(RP, Tin, pin)
[DinSuc, hinSuc] = fluidProp.getDh_from_TP(RP, Tsuc, Psuc)
hin, hinSuc
# Out:
# (105.1040826430525, 2696.341577082581)

# %%
nsolver = nozzleSolver.NozzleSolver(nozzle, fluid, 1, solver="AdamAdaptive", mode="basic")
nsolver.setFriction(1e-2)
vin_crit = nsolver.calcCriticalSpeed(pin, hin, 0.1, maxdev= 1e-3, chokePos="divergent_part" )
# Out:
# friction of the flow calc set to 0.01
# {'massflow': 0.09397797133719825}
# DEBUG:root:x: 0.0 stepsize corrected by 121.89011552554776
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 54.96825953581669
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 50.49016775338103
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.30000000000000004 stepsize corrected by 46.26210804788329
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.4 stepsize corrected by 42.27689875698646
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.5 stepsize corrected by 38.52735821806138
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.6 stepsize corrected by 35.006304768490864
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.7 stepsize corrected by 31.706556745587854
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.7999999999999999 stepsize corrected by 28.620932486594434
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.8999999999999999 stepsize corrected by 25.74225032864137
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.9999999999999999 stepsize corrected by 23.063328608704968
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 1.0999999999999999 stepsize corrected by 20.576985663675757
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 1.2 stepsize corrected by 18.27603983023103
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 1.3 stepsize corrected by 16.153309444853157
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 1.4000000000000001 stepsize corrected by 14.201612843775118
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 1.5000000000000002 stepsize corrected by 12.413768362829057
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 1.6000000000000003 stepsize corrected by 10.492392829333019
# DEBUG:root:new stepsize = 0.1
# INFO:root: x interval end reached xlast 4.300000000000001 +  dX 0.1 vs xend 4.316599999999999
# INFO:root:solver finished in 45 iterations. final point xlast =4.316599999999999
# {'massflow': 0.1879559426743965}
# DEBUG:root:x: 0.0 stepsize corrected by 60.94504983553165
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 27.48412533859346
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 25.2450791237448
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.30000000000000004 stepsize corrected by 23.131048944184258
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.4 stepsize corrected by 21.138443967312092
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.5 stepsize corrected by 19.263673360476083
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.6 stepsize corrected by 17.503146290765024
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.7 stepsize corrected by 15.853271925094813
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.7999999999999999 stepsize corrected by 13.524502470387967
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.8999999999999999 stepsize corrected by 11.320309096617557
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.600000000000001 stepsize corrected by 0.4729924855610453
# DEBUG:root:new stepsize = 0.04729924855610453
# DEBUG:root:x: 2.7891969942244184 stepsize corrected by 0.4626222354148706
# DEBUG:root:new stepsize = 0.021881684100468667
# INFO:root: x interval end reached xlast 4.299033197156756 +  dX 0.021881684100468667 vs xend 4.316599999999999
# INFO:root:solver finished in 101 iterations. final point xlast =4.316599999999999
# {'massflow': 0.375911885348793}
# DEBUG:root:x: 0.0 stepsize corrected by 24.337700297207842
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 10.100600635588547
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.41128248532964345
# DEBUG:root:new stepsize = 0.041128248532964345
# DEBUG:root:x: 2.5467694911977876 stepsize corrected by 0.4421637305462618
# DEBUG:root:new stepsize = 0.018185419802169332
# DEBUG:root:x: 2.7286236892194813 stepsize corrected by 0.4613024548648717
# DEBUG:root:new stepsize = 0.008388978797488962
# DEBUG:root:x: 2.8712363287767926 stepsize corrected by 0.47837133608403454
# DEBUG:root:new stepsize = 0.004013046995735432
# error occured in updaterFunction by 2.8953146107512047 dX : 0.004013046995735432
# [ 23.89859481   5.26815487 104.81923123]
# (<class 'ValueError'>, ValueError('unable to solve 1phase PY flash with Tmin=273.16, Tmax=3000 due to error: solver_rho_Tp was unable to find a solution for T=    273.16, p=  -395.042, with guess value  -0.173939 with error: The molar density of -0.173939 mol/m3 is below the minimum of 0.000000 mol/m3'), <traceback object at 0x7f81e3f59240>)
# DEBUG:root:update calculation failed
# DEBUG:root:xlast 2.8953146107512047, last calculation at x=2.89932765774694 :
# DEBUG:root:iter 64. try smaller stepsize dX = 4.013046995735432e-05
# DEBUG:root:x: 2.895354741221162 stepsize corrected by 17.949736912319032
# DEBUG:root:new stepsize = 0.0007203313779022328
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.040863782733751464
# INFO:root:Newton root finding failed at 2.8967954039769666 + 0.0007203313779022328
# DEBUG:root:update calculation failed
# DEBUG:root:xlast 2.8967954039769666, last calculation at x=2.897515735354869 :
# DEBUG:root:iter 67. try smaller stepsize dX = 7.203313779022328e-06
# DEBUG:root:x: 2.896802607290746 stepsize corrected by 99.15059366605615
# DEBUG:root:new stepsize = 0.0007142128375529463
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.040926798566260914
# INFO:root:Newton root finding failed at 2.896802607290746 + 0.0007142128375529463
# INFO:root:update failed by 2.896802607290746 with dX=0.0007142128375529463. stop solver
# 1.2
# result is between 0.6 and 1.2
# {'massflow': 0.28193391401159473}
# DEBUG:root:x: 0.0 stepsize corrected by 40.6300244157381
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 17.956629991294573
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 15.573007044641146
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.30000000000000004 stepsize corrected by 13.449499723239848
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.4 stepsize corrected by 11.564214388437964
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.400000000000001 stepsize corrected by 0.4990591054325638
# DEBUG:root:new stepsize = 0.04990591054325638
# DEBUG:root:x: 2.5996236421730257 stepsize corrected by 0.4983335820709646
# DEBUG:root:new stepsize = 0.024869791167534072
# DEBUG:root:x: 2.7737121803457634 stepsize corrected by 0.46333094800533065
# DEBUG:root:new stepsize = 0.01152294391834816
# INFO:root: x interval end reached xlast 4.306263721486071 +  dX 0.01152294391834816 vs xend 4.316599999999999
# INFO:root:solver finished in 170 iterations. final point xlast =4.316599999999999
# solution between 0.8999999999999999 - 1.2
# {'massflow': 0.32892289968019384}
# DEBUG:root:x: 0.0 stepsize corrected by 31.78802179033861
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 13.192623851388998
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 11.441390634696933
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.400000000000001 stepsize corrected by 0.3666499957926637
# DEBUG:root:new stepsize = 0.036664999579266375
# DEBUG:root:x: 2.6199899974756 stepsize corrected by 0.4738590628424109
# DEBUG:root:new stepsize = 0.017374042339748555
# DEBUG:root:x: 2.776356378533335 stepsize corrected by 0.4941066266940025
# DEBUG:root:new stepsize = 0.008584629452531934
# INFO:root: x interval end reached xlast 4.313005050536527 +  dX 0.008584629452531934 vs xend 4.316599999999999
# INFO:root:solver finished in 220 iterations. final point xlast =4.316599999999999
# solution between 1.0499999999999998 - 1.2
# {'massflow': 0.35241739251449344}
# DEBUG:root:x: 0.0 stepsize corrected by 27.690896844783946
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 11.492240121446057
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.467951240764614
# DEBUG:root:new stepsize = 0.0467951240764614
# DEBUG:root:x: 2.533975620382308 stepsize corrected by 0.4592248775883377
# DEBUG:root:new stepsize = 0.02148948512574406
# DEBUG:root:x: 2.705891501388259 stepsize corrected by 0.49188081921189225
# DEBUG:root:new stepsize = 0.010570265548092761
# DEBUG:root:x: 2.8538752190615586 stepsize corrected by 0.4735240758358413
# DEBUG:root:new stepsize = 0.005005275225000057
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.004260500951243529
# INFO:root:Newton root finding failed at 3.9700515942366192 + 0.005005275225000057
# DEBUG:root:update calculation failed
# DEBUG:root:xlast 3.9700515942366192, last calculation at x=3.9750568694616195 :
# DEBUG:root:iter 275. try smaller stepsize dX = 5.0052752250000566e-05
# DEBUG:root:x: 3.9701016469888692 stepsize corrected by 843.7348969706927
# DEBUG:root:new stepsize = 0.042231253762753836
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.042845475513075826
# INFO:root:Newton root finding failed at 3.9701016469888692 + 0.042231253762753836
# INFO:root:update failed by 3.9701016469888692 with dX=0.042231253762753836. stop solver
# solution between 1.0499999999999998 - 1.125
# {'massflow': 0.34067014609734364}
# DEBUG:root:x: 0.0 stepsize corrected by 29.633541187302377
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 12.298473974948182
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 10.665933132360323
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.400000000000001 stepsize corrected by 0.3417983088340043
# DEBUG:root:new stepsize = 0.03417983088340043
# DEBUG:root:x: 2.6392588161838026 stepsize corrected by 0.4368482192217243
# DEBUG:root:new stepsize = 0.014931398254713173
# DEBUG:root:x: 2.803504196985646 stepsize corrected by 0.4674745185986405
# DEBUG:root:new stepsize = 0.006980048211126621
# INFO:root: x interval end reached xlast 4.311194610588979 +  dX 0.006980048211126621 vs xend 4.316599999999999
# INFO:root:solver finished in 260 iterations. final point xlast =4.316599999999999
# solution between 1.0875 - 1.125
# {'massflow': 0.3465437693059185}
# DEBUG:root:x: 0.0 stepsize corrected by 28.637526749258445
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 11.885109294172308
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 10.307439828988294
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.48394921098401605
# DEBUG:root:new stepsize = 0.04839492109840161
# DEBUG:root:x: 2.5419746054920087 stepsize corrected by 0.4414947834208228
# DEBUG:root:new stepsize = 0.021366105209006628
# DEBUG:root:x: 2.7129034471640634 stepsize corrected by 0.4943414835009737
# DEBUG:root:new stepsize = 0.010562152145658218
# DEBUG:root:x: 2.860773577203276 stepsize corrected by 0.4709848215482896
# DEBUG:root:new stepsize = 0.004974613343488719
# INFO:root: x interval end reached xlast 4.313360673501976 +  dX 0.004974613343488719 vs xend 4.316599999999999
# INFO:root:solver finished in 344 iterations. final point xlast =4.316599999999999
# solution between 1.10625 - 1.125
# {'massflow': 0.34948058091020606}
# DEBUG:root:x: 0.0 stepsize corrected by 28.158245782599653
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 11.686198699878771
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 10.134933276450086
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.47584940070480686
# DEBUG:root:new stepsize = 0.04758494007048069
# DEBUG:root:x: 2.537924700352404 stepsize corrected by 0.4504019791558952
# DEBUG:root:new stepsize = 0.021432351185759167
# DEBUG:root:x: 2.709383509838476 stepsize corrected by 0.4930088382945522
# DEBUG:root:new stepsize = 0.010566338560011997
# DEBUG:root:x: 2.8573122496786425 stepsize corrected by 0.4722650723120785
# DEBUG:root:new stepsize = 0.004990112644117969
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.005068591191488281
# INFO:root:Newton root finding failed at 4.179692100369892 + 0.004990112644117969
# DEBUG:root:update calculation failed
# DEBUG:root:xlast 4.179692100369892, last calculation at x=4.18468221301401 :
# DEBUG:root:iter 317. try smaller stepsize dX = 4.9901126441179686e-05
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 5.1265883058718736e-05
# INFO:root:Newton root finding failed at 4.179742001496333 + 4.9901126441179686e-05
# DEBUG:root:update calculation failed
# DEBUG:root:xlast 4.179742001496333, last calculation at x=4.179791902622774 :
# DEBUG:root:iter 318. try smaller stepsize dX = 4.990112644117968e-07
# DEBUG:root:x: 4.179742500507597 stepsize corrected by 1951771.0399316822
# DEBUG:root:new stepsize = 0.1
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 939.5055164294242
# INFO:root:Newton root finding failed at 4.179742500507597 + 0.1
# INFO:root:update failed by 4.179742500507597 with dX=0.1. stop solver
# solution between 1.10625 - 1.115625
# {'massflow': 0.3480121751080622}
# DEBUG:root:x: 0.0 stepsize corrected by 28.396369563042903
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 11.785024536862947
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 10.220640649143501
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.47987367368562467
# DEBUG:root:new stepsize = 0.04798736736856247
# DEBUG:root:x: 2.539936836842814 stepsize corrected by 0.4459588306829827
# DEBUG:root:new stepsize = 0.02140039023923884
# DEBUG:root:x: 2.711139958756726 stepsize corrected by 0.49364884109139107
# DEBUG:root:new stepsize = 0.01056427784050377
# DEBUG:root:x: 2.8590398485237816 stepsize corrected by 0.4716276605622971
# DEBUG:root:new stepsize = 0.004982405643446909
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.0031277249867081025
# INFO:root:Newton root finding failed at 4.284007862549588 + 0.004982405643446909
# DEBUG:root:update calculation failed
# DEBUG:root:xlast 4.284007862549588, last calculation at x=4.288990268193035 :
# DEBUG:root:iter 338. try smaller stepsize dX = 4.982405643446909e-05
# DEBUG:root:x: 4.2840576866060225 stepsize corrected by 869.2073690245691
# DEBUG:root:new stepsize = 0.03254231339397684
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.03135337711327679
# INFO:root:Newton root finding failed at 4.2840576866060225 + 0.03254231339397684
# INFO:root:update failed by 4.2840576866060225 with dX=0.03254231339397684. stop solver
# solution between 1.10625 - 1.1109375
# {'massflow': 0.34727797220699036}
# DEBUG:root:x: 0.0 stepsize corrected by 28.516565772156994
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 11.834908219000956
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 10.263902608431698
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.4819049800761425
# DEBUG:root:new stepsize = 0.048190498007614255
# DEBUG:root:x: 2.5409524900380718 stepsize corrected by 0.44372940777919906
# DEBUG:root:new stepsize = 0.021383541141503346
# DEBUG:root:x: 2.7120208191700983 stepsize corrected by 0.4939884869938538
# DEBUG:root:new stepsize = 0.010563223135062062
# DEBUG:root:x: 2.8599059430609644 stepsize corrected by 0.47130692634550697
# DEBUG:root:new stepsize = 0.004978520228087851
# INFO:root: x interval end reached xlast 4.3136338496625575 +  dX 0.004978520228087851 vs xend 4.316599999999999
# INFO:root:solver finished in 344 iterations. final point xlast =4.316599999999999
# solution between 1.1085937499999998 - 1.1109375
# {'massflow': 0.3476450736575263}
# DEBUG:root:x: 0.0 stepsize corrected by 28.45637247529052
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 11.809926871326532
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 10.242237366433452
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.4808877181383472
# DEBUG:root:new stepsize = 0.048088771813834724
# DEBUG:root:x: 2.5404438590691734 stepsize corrected by 0.4448447708952609
# DEBUG:root:new stepsize = 0.021392038680159788
# DEBUG:root:x: 2.71158016851045 stepsize corrected by 0.49381700725717864
# DEBUG:root:new stepsize = 0.010563752520166312
# DEBUG:root:x: 2.859472703792781 stepsize corrected by 0.4714674639330747
# DEBUG:root:new stepsize = 0.004980465610299438
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.0011645461856346633
# INFO:root:Newton root finding failed at 4.30878819638991 + 0.004980465610299438
# DEBUG:root:update calculation failed
# DEBUG:root:xlast 4.30878819638991, last calculation at x=4.31376866200021 :
# DEBUG:root:iter 343. try smaller stepsize dX = 4.9804656102994376e-05
# DEBUG:root:x: 4.308838001046014 stepsize corrected by 871.383800089422
# DEBUG:root:new stepsize = 0.00776199895398566
# 3 dimensional Newton Raphson has not converged in 100 iterations
# error = 0.0040573828940573264
# INFO:root:Newton root finding failed at 4.308838001046014 + 0.00776199895398566
# INFO:root:update failed by 4.308838001046014 with dX=0.00776199895398566. stop solver
# solution between 1.1085937499999998 - 1.1097656249999999
# {'massflow': 0.3474615229322583}
# DEBUG:root:x: 0.0 stepsize corrected by 28.48644527534179
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 11.82240764763881
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 10.253061403733957
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.48139594607164155
# DEBUG:root:new stepsize = 0.04813959460716416
# DEBUG:root:x: 2.5406979730358223 stepsize corrected by 0.4442872520693562
# DEBUG:root:new stepsize = 0.021387808203749765
# DEBUG:root:x: 2.711800438665822 stepsize corrected by 0.4939023314328036
# DEBUG:root:new stepsize = 0.010563488336069652
# DEBUG:root:x: 2.8596892753707976 stepsize corrected by 0.471387237866007
# DEBUG:root:new stepsize = 0.004979493588969656
# INFO:root: x interval end reached xlast 4.313701403349941 +  dX 0.004979493588969656 vs xend 4.316599999999999
# INFO:root:solver finished in 344 iterations. final point xlast =4.316599999999999
# solution between 1.1091796874999997 - 1.1097656249999999
# bisection method 10 iterations in 1.883 + 13.611 sec
# critical speed calculation finished in 15.494 sec
# critical inlet velocity is 1.1091796874999997 m/s

# %%
vin_crit
# Out:
# 1.1091796874999997

# %%
sol_until_throat = nsolver.solveAdaptive1DBasic(vin_crit, pin, hin, 0.0, nsolver.nozzle.xt)
# In[9]:
dv_kick = 2.0
dp_kick = nsolver.pFromV_MassConst(v = sol_until_throat.iloc[-1]["v"], dv = dv_kick, p = sol_until_throat.iloc[-1]["p"], h = sol_until_throat.iloc[-1]["h"])
print(f"mass conserving artificial kick: dv = {dv_kick} m/s, dp = {dp_kick} kPa")
# Out:
# {'massflow': 0.3474615229322583}
# DEBUG:root:x: 0.0 stepsize corrected by 28.48644527534179
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.1 stepsize corrected by 11.82240764763881
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 0.2 stepsize corrected by 10.253061403733957
# DEBUG:root:new stepsize = 0.1
# DEBUG:root:x: 2.3000000000000007 stepsize corrected by 0.48139594607164155
# DEBUG:root:new stepsize = 0.04813959460716416
# DEBUG:root:x: 2.5406979730358223 stepsize corrected by 0.4442872520693562
# DEBUG:root:new stepsize = 0.021387808203749765
# DEBUG:root:x: 2.711800438665822 stepsize corrected by 0.4939023314328036
# DEBUG:root:new stepsize = 0.010563488336069652
# DEBUG:root:x: 2.8596892753707976 stepsize corrected by 0.471387237866007
# DEBUG:root:new stepsize = 0.004979493588969656
# INFO:root: x interval end reached xlast 2.9045047176715255 +  dX 0.004979493588969656 vs xend 2.905
# INFO:root:solver finished in 61 iterations. final point xlast =2.905
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       2 # In[9]:
#       3 dv_kick = 2.0
# ----> 4 dp_kick = nsolver.pFromV_MassConst(v = sol_until_throat.iloc[-1]["v"], dv = dv_kick, p = sol_until_throat.iloc[-1]["p"], h = sol_until_throat.iloc[-1]["h"])
#       5 print(f"mass conserving artificial kick: dv = {dv_kick} m/s, dp = {dp_kick} kPa")
#
# File /volume1/PROJECTS/MATACHANA/robert/python/simpy_steamEjector/src/simpy_ejector/flowSolver.py:356, in FlowSolver.pFromV_MassConst(self, v, dv, p, h)
#     346 """ Take a flow with a given speed(v), pressure(p) and TEmperature (T), search the the other pressure p+dp,
#     347 for which the mass flow remains the same, so
#     348  Density(p,h) * v = Density(p + dp, h ) * (v+dv)
#    (...)
#     353 :return : dp pressure difference in kPa
#     354 """
#     355 diffMF = lambda dpr : fluidProp.getTD(self.RP, h, p + dpr)['D']*(v+dv) - fluidProp.getTD(self.RP, h, p)['D'] * v
# --> 356 sol_dp = scipy.optimize.fsolve(diffMF, x0 = 0)[0]
#     357 return sol_dp
#
# File /volume1/opt/jupyterhub/jupyterhub-venv/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:170, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#     160 _wrapped_func.nfev = 0
#     162 options = {'col_deriv': col_deriv,
#     163            'xtol': xtol,
#     164            'maxfev': maxfev,
#    (...)
#     167            'factor': factor,
#     168            'diag': diag}
# --> 170 res = _root_hybr(_wrapped_func, x0, args, jac=fprime, **options)
#     171 res.nfev = _wrapped_func.nfev
#     173 if full_output:
#
# File /volume1/opt/jupyterhub/jupyterhub-venv/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:249, in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     247     if maxfev == 0:
#     248         maxfev = 200 * (n + 1)
# --> 249     retval = _minpack._hybrd(func, x0, args, 1, xtol, maxfev,
#     250                              ml, mu, epsfcn, factor, diag)
#     251 else:
#     252     _check_func('fsolve', 'fprime', Dfun, x0, args, n, (n, n))
#
# File /volume1/opt/jupyterhub/jupyterhub-venv/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:158, in fsolve.<locals>._wrapped_func(*fargs)
#     153 """
#     154 Wrapped `func` to track the number of times
#     155 the function has been called.
#     156 """
#     157 _wrapped_func.nfev += 1
# --> 158 return func(*fargs)
#
# File /volume1/PROJECTS/MATACHANA/robert/python/simpy_steamEjector/src/simpy_ejector/flowSolver.py:355, in FlowSolver.pFromV_MassConst.<locals>.<lambda>(dpr)
#     345 def pFromV_MassConst(self, v, dv, p, h):
#     346     """ Take a flow with a given speed(v), pressure(p) and TEmperature (T), search the the other pressure p+dp,
#     347     for which the mass flow remains the same, so
#     348      Density(p,h) * v = Density(p + dp, h ) * (v+dv)
#    (...)
#     353     :return : dp pressure difference in kPa
#     354     """
# --> 355     diffMF = lambda dpr : fluidProp.getTD(self.RP, h, p + dpr)['D']*(v+dv) - fluidProp.getTD(self.RP, h, p)['D'] * v
#     356     sol_dp = scipy.optimize.fsolve(diffMF, x0 = 0)[0]
#     357     return sol_dp
#
# File /volume1/PROJECTS/MATACHANA/robert/python/simpy_steamEjector/src/simpy_ejector/fluidProp.py:74, in getTD(FP, hm, P, debug)
#      72 hm *= 1000 # From kJ/kg to J/kg
#      73 P *= 1000 # From kPa to Pa
# ---> 74 res = FP.with_state(Input.pressure(P),Input.enthalpy(hm))
#      75 # print(res)
#      77 density = res.density
#
# File /volume1/opt/jupyterhub/jupyterhub-venv/lib/python3.10/site-packages/pyfluids/fluids/abstract_fluid.py:327, in AbstractFluid.with_state(self, first_input, second_input)
#     325 if self.__specified_phase is not None:
#     326     fluid.specify_phase(self.__specified_phase)
# --> 327 fluid.update(first_input, second_input)
#     328 return fluid
#
# File /volume1/opt/jupyterhub/jupyterhub-venv/lib/python3.10/site-packages/pyfluids/fluids/abstract_fluid.py:341, in AbstractFluid.update(self, first_input, second_input)
#     339     raise ValueError("Need to define 2 unique inputs!")
#     340 self.reset()
# --> 341 self._backend.update(
#     342     *generate_update_pair(
#     343         first_input.coolprop_key,
#     344         first_input.value,
#     345         second_input.coolprop_key,
#     346         second_input.value,
#     347     )
#     348 )
#     349 self._inputs = [first_input, second_input]
#
# File CoolProp/AbstractState.pyx:102, in CoolProp.CoolProp.AbstractState.update()
#
# File CoolProp/AbstractState.pyx:104, in CoolProp.CoolProp.AbstractState.update()
#
# ValueError: unable to solve 1phase PY flash with Tmin=273.16, Tmax=3000 due to error: solver_rho_Tp was unable to find a solution for T=    273.16, p=-1.43222e+06, with guess value   -630.614 with error: The molar density of -630.614214 mol/m3 is below the minimum of 0.000000 mol/m3

# %%
res_crit = nsolver.solveKickedNozzle(vin_crit, pin , hin, kicks = {'v': dv_kick , 'p': -dp_kick})
nsolver.plotsol(res_crit, title = "choked nozzle with friction = {} ".format(nsolver.frictionCoef))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 res_crit = nsolver.solveKickedNozzle(vin_crit, pin , hin, kicks = {'v': dv_kick , 'p': -dp_kick})
#       2 nsolver.plotsol(res_crit, title = "choked nozzle with friction = {} ".format(nsolver.frictionCoef))
#
# NameError: name 'dp_kick' is not defined

# %%
nozzleExit =  res_crit.iloc[-1]
nozzleExit
# Out:
# x            4.316600
# v          402.597917
# p          273.397534
# h          628.648932
# d            6.368739
# c          211.686835
# mach         1.901856
# quality      0.000000
# Name: 3133, dtype: float64

# %%
plt.figure()
plt.plot(res_crit['x'], res_crit['v'])
plt.plot(res_crit['x'], res_crit['c'])
plt.legend(["velocity", "speed of sound"])

# %%
massFlowPrim = nozzleExit['v']* nozzleExit['d']* nozzle.Aprofile(nozzle.L) * 1e-4
massFlowPrim # in kg/sec
# Out:
# 0.09587668964881303

# %%
mixingParams = { 'massExchangeFactor' : 1.e-4, 'dragFactor': 0.003, 'frictionInterface': 0.001, 'frictionWall': 0.015}
mixer = EjectorMixer.EjectorMixer(fluid, ejector, mixingParams)

# %%
calcSucMassFlow = True
if calcSucMassFlow == False:
    # Single Choking calculation. With externally set suction mass flow rate:
    MFlowSuc = 58.0
    mixer.setSuctionMassFlow(MFlowSuc) # set the suction mass flow rate in [g/s]b

    entrainment = mixer.massFlowSecond / 1000.0 / massFlowPrim
    entrainment

    preMix = mixer.premixWrapSolve(res_crit, Psuc ,Tsuc)
    preMix
    mixerinput = [ preMix[key] for key in [  'py', 'vpy', 'vsy', 'hpy', 'hsy', 'Apy', 'Asy']]

    solMix = mixer.solveMix(mixerinput)
else:
    mixer.setSuctionMassFlow(None)
    mixer.setSingleChoke(True)
    mixer.ejector.Asi = 2* 1.1**2 * math.pi  # cm2 of the suction nozzle inlet.
    #mixer.ejector.Asi = 2*3.14*3.25*2.2
    preMix = mixer.premixWrapSolve(res_crit, Psuc ,Tsuc)
    preMix
    print(f"calculated secondary mass flow rate {preMix['massFlowSecond']} g/s")
    mixerinput = [ preMix[key] for key in [  'py', 'vpy', 'vsy', 'hpy', 'hsy', 'Apy', 'Asy']]
    solMix = mixer.solveMix(mixerinput)
# Out:
# critical flow nozzle outlet quantities
#                3133
# x          4.316600
# v        402.597917
# p        273.397534
# h        628.648932
# d          6.368739
# c        211.686835
# mach       1.901856
# quality    0.000000
# INFO:root:suction flow by inlet Dens 10.13456764449752 g/l, quality 0.0
# INFO:root:calculation of single-chocking subcritical mode incl. suction mass flow rate calculations
# {'Tsi': 325.84999999999997, 'psi': 430, 'massFlowPrim': 95.87668964881303, 'ho': 628.6489319602777, 'vo': 402.5979172412707, 'so': 2.4734978986042107, 'Am': 1.5393804002589984}
# INFO:root:solving equation for 10 variables in solvePreMixSingleChoke with parameters:
#  {'Tsi': 325.84999999999997, 'psi': 430, 'massFlowPrim': 95.87668964881303, 'ho': 628.6489319602777, 'vo': 402.5979172412707, 'so': 2.4734978986042107, 'Am': 1.5393804002589984, 'sp': 2.4734978986042107, 'Dsi': 10.13456764449752, 'hsi': 635.9914487599148, 'hst': 635.9914487599148, 'sst': 2.4362554911605505, 'Asi': 7.602654221687301}
# INFO:root:premix calculation finished after 120 function evaluations:
#  The relative error between two consecutive iterates is at most 0.000010
# INFO:root: error terms in solving the solvePreMixSingleChoke:
#  [2.7199718033443787e-09, -6.35751007393992e-10, 6.499302429574527e-09, 1.7685175324189117e-07, 1.389433634813031e-08, 2.3515366196491527e-06, -1.8227227194245188e-07, -0.0007593114721808902, 0.0001792894909158349]
#  for the equations: [massp, enp, dp, Sp, masssec, ens, ds, Ss, dMomS]
# INFO:root:Tot premix precision -5.7765e-04 momentum equation err = 1.7929e-04
# INFO:root:pre-mix calculations with single choking and suction mass flow rate calculation
# at Y point after pre-mixing
# {'py': 377.9260137494697, 'vpy': 366.2217746474876, 'hpy': 642.6322793314403, 'Dpy': 8.704633004483373, 'Apy': 0.30075884078447795, 'vsy': 103.2993036728096, 'hsy': 630.7659455242962, 'Dsy': 8.926748823278363, 'Asy': 1.2386215594745205, 'massFlowSecond': 114.21663055069897}
# Pressure[kPa] suction 430 . primary nozzle exit : 273.398
# equalized pressure after pre-mixing : 378 kPa
# cross section area nozzle exit 0.374 Mixer full: 1.539 cm^2
# A at pre-mix end (Y) suction/secondary 1.2386 A primary flow : 0.301 cm^2
# mass flow [g/sec]  suction/secondary 114.2166 primary flow : 95.877
# mass flow rate, entrainment ratio = 1.1912867556135214
# calculated secondary mass flow rate 114.21663055069897 g/s

# %%
print(solMix)
# Out:
#              x           p          vp          vs          hp          hs        Ap        As
# 0     5.514000  377.926025  366.221771  103.299301  642.632263  630.765930  0.300759  1.238622
# 1     5.696915  385.749695  355.928351  101.374445  646.411084  630.910703  0.305566  1.233815
# 2     5.879829  393.056637  346.201437   99.679260  649.877642  631.037491  0.310537  1.228844
# 3     6.062744  399.897839  336.998453   98.179869  653.063962  631.149865  0.315643  1.223737
# 4     6.245658  406.316545  328.281321   96.849128  655.998011  631.250526  0.320863  1.218517
# ..         ...         ...         ...         ...         ...         ...       ...       ...
# 195  41.182342  600.422538   34.422866    9.620442  703.756991  641.265358  2.475793  7.347369
# 196  41.365256  600.458219   34.158074    9.527381  703.746008  641.287560  2.495585  7.416478
# 197  41.548171  600.493120   33.896309    9.435664  703.734942  641.309660  2.515462  7.485902
# 198  41.731085  600.527261   33.637527    9.345264  703.723796  641.331659  2.535423  7.555642
# 199  41.914000  600.560662   33.381682    9.256157  703.712573  641.353558  2.555468  7.625698
#
# [200 rows x 8 columns]

# %%
mixer.plotSolution(res_crit, solMix, "single choking mode",  ejectorPlot)

# %%
Pdiffout = solMix.iloc[-1]['p']
Pdiffout
# Out:
# 600.560661768418

# %%
# Ejector Pressure Lift in kPa

Pdiffout - Psuc
# Out:
# 170.56066176841796

# %%
# Ejector efficiency:

diffusorLast =  solMix.iloc[-1]
diffusorLast
# Out:
# x      41.914000
# p     600.560662
# vp     33.381682
# vs      9.256157
# hp    703.712573
# hs    641.353558
# Ap      2.555468
# As      7.625698
# Name: 199, dtype: float64

# %%
# We need to calculate the average spec enthalpy, for that we need the mass flow rates
primState =  fluidProp.getTD(RP, diffusorLast['hp'] , diffusorLast['p'])
secState = fluidProp.getTD(RP, diffusorLast['hs'] , diffusorLast['p'])
primState, secState
# Out:
# ({'T': 89.40628543074342,
#   'D': 12.699613598959232,
#   'q': 0.0,
#   'c': 218.44067361655658,
#   's': 2.5894906932107644},
#  {'T': 58.601416313699815,
#   'D': 14.415621816275959,
#   'q': 0.0,
#   'c': 202.93236571289822,
#   's': 2.4098007813314255})

# %%
massFPrim = primState['D'] * diffusorLast['vp']* diffusorLast['Ap']* 1e-4
massFSec = primState['D'] * diffusorLast['vs']* diffusorLast['As']* 1e-4
massFPrim , massFSec
# Out:
# (0.10833511190584011, 0.08963979140343614)

# %%
hAverage = (massFPrim * diffusorLast['hp'] + massFSec * diffusorLast['hs'] )/ (massFPrim + massFSec )
hAverage
# Out:
# 675.4774327152334

# %%
hin,hinSuc,Psuc
# Out:
# (709.2909050579749, 635.9914487599148, 430)

# %%
efficiency = mixer.calcEfficiency(pin, Tin, Psuc, Tsuc, Pdiffout, massFPrim , massFSec )
# Out:
#  Expansion work recovered : -58.4915817372128 Watt.
#   max expansion work recovery potential 78.63118323273974 Watt

# %%
efficiency
# Out:
# -0.7438725875977737

# %%
def specPlotSolution(ejector, RP, solNozzle, solMix, title="", ejectorPlot=True,
                     pressureExp = None):
    """ Plot the results of solveMix function
    :param solNozzle: solution of the nozzle
    :param solMix: the solution dataframe with data that we get from the solveMix function
    :return:
    """
    fig = plt.figure(figsize=[11, 8])
    fig.suptitle("results of the 1D flow ejector simulation \n " + title)
    if (ejectorPlot):
        plt.subplot(311)
        # plt.plot(ejectorPlot)
        nozzleWall = [ejector.nozzle.Rprofile(xi) for xi in solNozzle['x']]
        mixerWall = [ejector.mixerR(xi) for xi in solMix['x']]
        plt.plot(solNozzle['x'], nozzleWall)
        plt.plot(solMix['x'], np.sqrt(solMix['Ap'] / math.pi))
        plt.plot(solMix['x'], mixerWall)
        plt.legend(['wall of Nozzle', 'primary motive stream', 'wall of Mixing region'])
        plt.ylabel("R [cm]")

    if ejectorPlot:
        plt.subplot(312)
    else:
        plt.subplot(211)
    if pressureExp is None:
        plt.plot(solNozzle['x'], solNozzle['p'], color = 'C0')
        plt.plot(solMix['x'], solMix['p'], color='C0')
        # speeds
        plt.plot(solNozzle['x'], solNozzle['v'], color="#aa1111")
        plt.plot(solMix['x'], solMix['vp'], color="#aa1111")
        plt.plot(solMix['x'], solMix['vs'], color="#aa9911")
        ## enthalpy
        plt.plot(solMix['x'], solMix['hp'])
        plt.legend(['pressure [kPa]', 'p [kPa]',
                    'prim flow speed', 'prim flow speed', 'suction flow speed',
                    'hp'])
        plt.yscale("log")
        plt.xlabel("x [cm]")
    else:
        plt.plot(solNozzle['x'], solNozzle['p'], color='C0')
        plt.plot(solMix['x'], solMix['p'], color='C0')
        plt.plot(pressureExp['x'], pressureExp['p'], color = 'red', marker = 'x', linestyle = '')
        plt.legend(['pressure simulation [kPa]', '',
                    'pressure Experiments [kPa]' ] )
        plt.xlabel("x [cm]")
        plt.ylabel("kPa")
        plt.yscale("log")
        plt.grid(True, axis = 'y')
    ## Mach numbers :
    if ejectorPlot:
        plt.subplot(313)
    else:
        plt.subplot(212)
    plt.plot(solNozzle['x'], solNozzle['mach'], color = 'C0')
    cPrim = [refProp.getSpeedSound(RP, solMix.iloc[i]['hp'], solMix.iloc[i]['p']) for i in range(solMix.__len__())]
    cSec = [refProp.getSpeedSound(RP, solMix.iloc[i]['hs'], solMix.iloc[i]['p']) for i in
            range(solMix.__len__())]
    plt.plot(solMix['x'], solMix['vp'] / cPrim, color = 'C0')
    plt.plot(solMix['x'], solMix['vs'] / cSec, color = 'C1' )
    plt.legend(['primary Mach', 'primary Mach', 'secondary Mach'])
    plt.tight_layout()
    plt.axvline( x = ejector.nozzle.xt, linestyle = '--', color = '#444444' )
    plt.text(ejector.nozzle.xt, 0.0, 'motive nozzle throat', va = 'bottom', rotation = 90, alpha = 0.6)
    # text1 = plt.annotate('motive nozzle throat', xy=(ejector.nozzle.xt, 0.3), va='top', rotation = 90)
    # text1.set_alpha(.7)
    mixend = ejector.ejectorlength - ejector.diffuserLen
    plt.axvline( x = mixend, linestyle = '--', color = '#444444' )
    text2 = plt.annotate('diffuser', xy=(mixend, 0), va='bottom',alpha = 0.6)
    # text2.set_alpha(.7)

# %%
pressureExp = pd.DataFrame( {'x': [ 5.5, 11.1, 16.7, 29.3, 41.9],
                              'p' : [ 404.4, 461.7, 520.2, 579.2, 584.5]})

# %%
specPlotSolution(ejector, RP, res_crit, solMix, "single choking mode",  False, pressureExp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 specPlotSolution(ejector, RP, res_crit, solMix, "single choking mode",  False, pressureExp)
#
# Cell In[30], line 55, in specPlotSolution(ejector, RP, solNozzle, solMix, title, ejectorPlot, pressureExp)
#      53     plt.subplot(212)
#      54 plt.plot(solNozzle['x'], solNozzle['mach'], color = 'C0')
# ---> 55 cPrim = [refProp.getSpeedSound(RP, solMix.iloc[i]['hp'], solMix.iloc[i]['p']) for i in range(solMix.__len__())]
#      56 cSec = [refProp.getSpeedSound(RP, solMix.iloc[i]['hs'], solMix.iloc[i]['p']) for i in
#      57         range(solMix.__len__())]
#      58 plt.plot(solMix['x'], solMix['vp'] / cPrim, color = 'C0')
#
# Cell In[30], line 55, in <listcomp>(.0)
#      53     plt.subplot(212)
#      54 plt.plot(solNozzle['x'], solNozzle['mach'], color = 'C0')
# ---> 55 cPrim = [refProp.getSpeedSound(RP, solMix.iloc[i]['hp'], solMix.iloc[i]['p']) for i in range(solMix.__len__())]
#      56 cSec = [refProp.getSpeedSound(RP, solMix.iloc[i]['hs'], solMix.iloc[i]['p']) for i in
#      57         range(solMix.__len__())]
#      58 plt.plot(solMix['x'], solMix['vp'] / cPrim, color = 'C0')
#
# NameError: name 'refProp' is not defined
